# %%
import pandas as pd
import numpy as np
import requests

# %%
url = "https://api.coingecko.com/api/v3/"
headers = { 'Content-type': 'application/json'}

# %%
r = requests.get(url + 'ping', headers = headers).json()

# %%
r
# Out:
# {'gecko_says': '(V3) To the Moon!'}

# %%
payload = {'vs_currency': 'usd', 'per_page':'250'}

# %% [markdown]
# Pull markets from Coingecko

# %%
r = requests.get(url + 'coins/markets', params=payload, headers = headers).json()
# Work with Pagination for more than 250 coins

# %%
df = pd.DataFrame(r)

# %%
df.head()
# Out:
#             id symbol      name  \
# 0      bitcoin    btc   Bitcoin
# 1     ethereum    eth  Ethereum
# 2       tether   usdt    Tether
# 3     usd-coin   usdc  USD Coin
# 4  binancecoin    bnb       BNB
#
#                                                image  current_price  \
# 0  https://assets.coingecko.com/coins/images/1/la...      19884.000
# 1  https://assets.coingecko.com/coins/images/279/...       1078.760
# 2  https://assets.coingecko.com/coins/images/325/...          1.001
# 3  https://assets.coingecko.com/coins/images/6319...          1.002
# 4  https://assets.coingecko.com/coins/images/825/...        227.730
#
#      market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0  379183186760                1             4.170648e+11  2.244597e+10
# 1  128848399714                2                      NaN  1.245232e+10
# 2   66017139429                3                      NaN  4.667635e+10
# ...

# %%
coin_id = 'bitcoin'

# %%
payload = {'coin_id': coin_id}

# %%
coinrequest = requests.get(url + 'coins/' + coin_id, params=payload, headers = headers).json()

# %%
coinrequest
# Out:
# {'id': 'bitcoin',
#  'symbol': 'btc',
#  'name': 'Bitcoin',
#  'asset_platform_id': None,
#  'platforms': {'': ''},
#  'block_time_in_minutes': 10,
#  'hashing_algorithm': 'SHA-256',
#  'categories': ['Cryptocurrency'],
#  'public_notice': None,
#  'additional_notices': [],
#  'localization': {'en': 'Bitcoin',
#   'de': 'Bitcoin',
#   'es': 'Bitcoin',
#   'fr': 'Bitcoin',
#   'it': 'Bitcoin',
#   'pl': 'Bitcoin',
#   'ro': 'Bitcoin',
#   'hu': 'Bitcoin',
#   'nl': 'Bitcoin',
#   'pt': 'Bitcoin',
#   'sv': 'Bitcoin',
#   'vi': 'Bitcoin',
#   'tr': 'Bitcoin',
#   'ru': 'Биткоин',
#   'ja': 'ビットコイン',
#   'zh': '比特币',
#   'zh-tw': '比特幣',
#   'ko': '비트코인',
#   'ar': 'بيتكوين',
#   'th': 'บิตคอยน์',
#   'id': 'Bitcoin',
#   'cs': 'Bitcoin',
#   'da': 'Bitcoin',
#   'el': 'Bitcoin',
#   'hi': 'Bitcoin',
#   'no': 'Bitcoin',
#   'sk': 'Bitcoin',
#   'uk': 'Bitcoin',
#   'he': 'Bitcoin',
#   'fi': 'Bitcoin',
#   'bg': 'Bitcoin',
#   'hr': 'Bitcoin',
#   'lt': 'Bitcoin',
#   'sl': 'Bitcoin'},
# ...

# %%
test = pd.DataFrame.from_dict(coinrequest, orient='index')
test = test.transpose()
test
# Out:
#         id symbol     name asset_platform_id platforms block_time_in_minutes  \
# 0  bitcoin    btc  Bitcoin              None  {'': ''}                    10
#
#   hashing_algorithm        categories public_notice additional_notices  ...  \
# 0           SHA-256  [Cryptocurrency]          None                 []  ...
#
#   community_score liquidity_score public_interest_score  \
# 0          80.197          99.999                 0.112
#
#                                          market_data  \
# 0  {'current_price': {'aed': 73035, 'ars': 253649...
#
#                                       community_data  \
# 0  {'facebook_likes': None, 'twitter_followers': ...
#
#                                       developer_data  \
# 0  {'forks': 32676, 'stars': 65173, 'subscribers'...
#
#                         public_interest_stats status_updates  \
# 0  {'alexa_rank': 9440, 'bing_matches': None}             []
#
# ...

# %%
df.merge(test, how='outer', on='id').head()
# Out:
#             id symbol_x    name_x  \
# 0      bitcoin      btc   Bitcoin
# 1     ethereum      eth  Ethereum
# 2       tether     usdt    Tether
# 3     usd-coin     usdc  USD Coin
# 4  binancecoin      bnb       BNB
#
#                                              image_x  current_price  \
# 0  https://assets.coingecko.com/coins/images/1/la...      19884.000
# 1  https://assets.coingecko.com/coins/images/279/...       1078.760
# 2  https://assets.coingecko.com/coins/images/325/...          1.001
# 3  https://assets.coingecko.com/coins/images/6319...          1.002
# 4  https://assets.coingecko.com/coins/images/825/...        227.730
#
#      market_cap  market_cap_rank_x  fully_diluted_valuation  total_volume  \
# 0  379183186760                  1             4.170648e+11  2.244597e+10
# 1  128848399714                  2                      NaN  1.245232e+10
# 2   66017139429                  3                      NaN  4.667635e+10
# ...
