# %%
import pandas as pd
import numpy as np
import requests
import json

# %%
API_KEY = open('../API_Messari.txt', 'r')
print(API_KEY)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [8], in <module>
# ----> 1 API_KEY = open('../API_Messari.txt', 'r')
#       2 print(API_KEY)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../API_Messari.txt'

# %%
url = "https://data.messari.io/api/v2/"
headers = { 'Content-type': 'application/json', "x-messari-api-key": "YOUR-SECRET-KEY"}
payload = {'page': '1'}

# %%
r = requests.get(url + 'assets',params=payload, headers = headers).json()

# %%
df = pd.DataFrame.from_dict(r['data'])
df = df.add_suffix( "_ms")

# %%
df.head()
# Out:
#                                   id_ms  serial_id_ms symbol_ms   name_ms  \
# 0  1e31218a-e44e-4285-820c-8282ee222035          6057       BTC   Bitcoin
# 1  21c795f5-1bfd-40c3-858e-e9d7e820c6d0          6059       ETH  Ethereum
# 2  51f8ea5e-f426-4f40-939a-db7e05495374           140      USDT    Tether
# 3  4515ba15-2719-4183-b0ca-b9255d55b67e          6071      USDC  USD Coin
# 4  7dc551ba-cfed-4437-a027-386044415e3e           347       BNB       BNB
#
#         slug_ms                              contract_addresses_ms  \
# 0       bitcoin                                               None
# 1      ethereum                                               None
# 2        tether  [{'platform': 'polygon-pos', 'contract_address...
# 3      usd-coin  [{'platform': 'milkomeda-cardano', 'contract_a...
# 4  binance-coin                                               None
#
#              _internal_temp_agora_id_ms  \
# 0  9793eae6-f374-46b4-8764-c2d224429791
# 1  263d8b01-5a96-41f0-85d5-09687bbbf7ca
# 2  1eaf063a-b8dd-4cfb-95dd-a06338565720
# 3  df532106-d330-46aa-b0fb-1b51f201e80e
# 4  3f1d591f-979c-453b-954b-aa90edf29a2a
#
#                                           metrics_ms  \
# 0  {'market_data': {'price_usd': 23007.5327492716...
# 1  {'market_data': {'price_usd': 1489.25257896044...
# 2  {'market_data': {'price_usd': 0.99990948326514...
# 3  {'market_data': {'price_usd': 1, 'price_btc': ...
# 4  {'market_data': {'price_usd': 256.334565336979...
#
#                                           profile_ms
# 0  {'general': {'overview': {'is_verified': False...
# 1  {'general': {'overview': {'is_verified': False...
# 2  {'general': {'overview': {'is_verified': False...
# 3  {'general': {'overview': {'is_verified': False...
# 4  {'general': {'overview': {'is_verified': False...

# %%
df.to_csv('../data/messari.csv')
