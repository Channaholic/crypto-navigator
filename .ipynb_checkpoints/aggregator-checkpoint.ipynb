# %%
import pandas as pd
import numpy as np
import json
import ast

# %%
messari = pd.read_csv('../data/messari.csv', index_col=0)
cg = pd.read_csv('../data/cg.csv', index_col=0)

# %%
messari.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id_ms                       20 non-null     object
#  1   serial_id_ms                20 non-null     int64
#  2   symbol_ms                   20 non-null     object
#  3   name_ms                     20 non-null     object
#  4   slug_ms                     20 non-null     object
#  5   contract_addresses_ms       10 non-null     object
#  6   _internal_temp_agora_id_ms  20 non-null     object
#  7   metrics_ms                  20 non-null     object
#  8   profile_ms                  20 non-null     object
# dtypes: int64(1), object(8)
# memory usage: 1.6+ KB

# %%
cg.rename(columns={"symbol_x_cg": "symbol_ms", "name_x_cg": "name_ms"}, inplace=True)

# %%
cg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 0 to 14
# Data columns (total 59 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id_cg                                15 non-null     object
#  1   symbol_ms                            15 non-null     object
#  2   name_ms                              15 non-null     object
#  3   image_x_cg                           15 non-null     object
#  4   current_price_cg                     15 non-null     float64
#  5   market_cap_cg                        15 non-null     int64
#  6   market_cap_rank_x_cg                 15 non-null     int64
#  7   fully_diluted_valuation_cg           7 non-null      float64
#  8   total_volume_cg                      15 non-null     int64
#  9   high_24h_cg                          15 non-null     float64
#  10  low_24h_cg                           15 non-null     float64
#  11  price_change_24h_cg                  15 non-null     float64
#  12  price_change_percentage_24h_cg       15 non-null     float64
#  13  market_cap_change_24h_cg             15 non-null     float64
#  14  market_cap_change_percentage_24h_cg  15 non-null     float64
#  15  circulating_supply_cg                15 non-null     float64
#  16  total_supply_cg                      14 non-null     float64
#  17  max_supply_cg                        7 non-null      float64
#  18  ath_cg                               15 non-null     float64
#  19  ath_change_percentage_cg             15 non-null     float64
#  20  ath_date_cg                          15 non-null     object
#  21  atl_cg                               15 non-null     float64
#  22  atl_change_percentage_cg             15 non-null     float64
#  23  atl_date_cg                          15 non-null     object
#  24  roi_cg                               2 non-null      object
#  25  last_updated_x_cg                    15 non-null     object
#  26  symbol_y_cg                          15 non-null     object
#  27  name_y_cg                            15 non-null     object
#  28  asset_platform_id_cg                 7 non-null      object
#  29  platforms_cg                         15 non-null     object
#  30  block_time_in_minutes_cg             15 non-null     int64
#  31  hashing_algorithm_cg                 3 non-null      object
#  32  categories_cg                        15 non-null     object
#  33  public_notice_cg                     0 non-null      float64
#  34  additional_notices_cg                15 non-null     object
#  35  localization_cg                      15 non-null     object
#  36  description_cg                       15 non-null     object
#  37  links_cg                             15 non-null     object
#  38  image_y_cg                           15 non-null     object
#  39  country_origin_cg                    2 non-null      object
#  40  genesis_date_cg                      4 non-null      object
#  41  sentiment_votes_up_percentage_cg     15 non-null     float64
#  42  sentiment_votes_down_percentage_cg   15 non-null     float64
#  43  market_cap_rank_y_cg                 15 non-null     int64
#  44  coingecko_rank_cg                    15 non-null     int64
#  45  coingecko_score_cg                   15 non-null     float64
#  46  developer_score_cg                   15 non-null     float64
#  47  community_score_cg                   15 non-null     float64
#  48  liquidity_score_cg                   15 non-null     float64
#  49  public_interest_score_cg             15 non-null     float64
#  50  market_data_cg                       15 non-null     object
#  51  community_data_cg                    15 non-null     object
#  52  developer_data_cg                    15 non-null     object
#  53  public_interest_stats_cg             15 non-null     object
#  54  status_updates_cg                    15 non-null     object
#  55  last_updated_y_cg                    15 non-null     object
#  56  tickers_cg                           15 non-null     object
#  57  ico_data_cg                          3 non-null      object
#  58  contract_address_cg                  7 non-null      object
# dtypes: float64(23), int64(6), object(30)
# memory usage: 7.0+ KB

# %%
df = messari.merge(cg, how='outer', on='name_ms')

# %%
profile = df.iloc[0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 0 to 19
# Data columns (total 67 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id_ms                                20 non-null     object
#  1   serial_id_ms                         20 non-null     int64
#  2   symbol_ms_x                          20 non-null     object
#  3   name_ms                              20 non-null     object
#  4   slug_ms                              20 non-null     object
#  5   contract_addresses_ms                10 non-null     object
#  6   _internal_temp_agora_id_ms           20 non-null     object
#  7   metrics_ms                           20 non-null     object
#  8   profile_ms                           20 non-null     object
#  9   id_cg                                15 non-null     object
#  10  symbol_ms_y                          15 non-null     object
#  11  image_x_cg                           15 non-null     object
#  12  current_price_cg                     15 non-null     float64
#  13  market_cap_cg                        15 non-null     float64
#  14  market_cap_rank_x_cg                 15 non-null     float64
#  15  fully_diluted_valuation_cg           7 non-null      float64
#  16  total_volume_cg                      15 non-null     float64
#  17  high_24h_cg                          15 non-null     float64
#  18  low_24h_cg                           15 non-null     float64
#  19  price_change_24h_cg                  15 non-null     float64
#  20  price_change_percentage_24h_cg       15 non-null     float64
#  21  market_cap_change_24h_cg             15 non-null     float64
#  22  market_cap_change_percentage_24h_cg  15 non-null     float64
#  23  circulating_supply_cg                15 non-null     float64
#  24  total_supply_cg                      14 non-null     float64
#  25  max_supply_cg                        7 non-null      float64
#  26  ath_cg                               15 non-null     float64
#  27  ath_change_percentage_cg             15 non-null     float64
#  28  ath_date_cg                          15 non-null     object
#  29  atl_cg                               15 non-null     float64
#  30  atl_change_percentage_cg             15 non-null     float64
#  31  atl_date_cg                          15 non-null     object
#  32  roi_cg                               2 non-null      object
#  33  last_updated_x_cg                    15 non-null     object
#  34  symbol_y_cg                          15 non-null     object
#  35  name_y_cg                            15 non-null     object
#  36  asset_platform_id_cg                 7 non-null      object
#  37  platforms_cg                         15 non-null     object
#  38  block_time_in_minutes_cg             15 non-null     float64
#  39  hashing_algorithm_cg                 3 non-null      object
#  40  categories_cg                        15 non-null     object
#  41  public_notice_cg                     0 non-null      float64
#  42  additional_notices_cg                15 non-null     object
#  43  localization_cg                      15 non-null     object
#  44  description_cg                       15 non-null     object
#  45  links_cg                             15 non-null     object
#  46  image_y_cg                           15 non-null     object
#  47  country_origin_cg                    2 non-null      object
#  48  genesis_date_cg                      4 non-null      object
#  49  sentiment_votes_up_percentage_cg     15 non-null     float64
#  50  sentiment_votes_down_percentage_cg   15 non-null     float64
#  51  market_cap_rank_y_cg                 15 non-null     float64
#  52  coingecko_rank_cg                    15 non-null     float64
#  53  coingecko_score_cg                   15 non-null     float64
#  54  developer_score_cg                   15 non-null     float64
#  55  community_score_cg                   15 non-null     float64
#  56  liquidity_score_cg                   15 non-null     float64
#  57  public_interest_score_cg             15 non-null     float64
#  58  market_data_cg                       15 non-null     object
#  59  community_data_cg                    15 non-null     object
#  60  developer_data_cg                    15 non-null     object
#  61  public_interest_stats_cg             15 non-null     object
#  62  status_updates_cg                    15 non-null     object
#  63  last_updated_y_cg                    15 non-null     object
#  64  tickers_cg                           15 non-null     object
#  65  ico_data_cg                          3 non-null      object
#  66  contract_address_cg                  7 non-null      object
# dtypes: float64(29), int64(1), object(37)
# memory usage: 10.6+ KB

# %%
pd.json_normalize(ast.literal_eval(df.iloc[7]['market_data_cg']), max_level=0)
# Out:
#                                        current_price total_value_locked  \
# 0  {'aed': 1.8, 'ars': 63.59, 'aud': 0.71479, 'bc...               None
#
#   mcap_to_tvl_ratio fdv_to_tvl_ratio   roi  \
# 0              None             None  None
#
#                                                  ath  \
# 0  {'aed': 11.34, 'ars': 301.61, 'aud': 4.19, 'bc...
#
#                                ath_change_percentage  \
# 0  {'aed': -84.0624, 'ars': -78.89372, 'aud': -82...
#
#                                             ath_date  \
# 0  {'aed': '2021-09-02T06:00:10.474Z', 'ars': '20...
#
#                                                  atl  \
# 0  {'aed': 0.070719, 'ars': 0.373473, 'aud': 0.02...
#
#                                atl_change_percentage  ...  \
# 0  {'aed': 2455.24171, 'ars': 16945.20237, 'aud':...  ...
#
#              price_change_percentage_30d_in_currency  \
# 0  {'aed': -0.27932, 'ars': 5.02755, 'aud': 1.133...
#
#              price_change_percentage_60d_in_currency  \
# 0  {'aed': -7.1938, 'ars': 1.39181, 'aud': -5.006...
#
#             price_change_percentage_200d_in_currency  \
# 0  {'aed': -64.35, 'ars': -55.07701, 'aud': -62.3...
#
#               price_change_percentage_1y_in_currency  \
# 0  {'aed': -53.6462, 'ars': -37.72777, 'aud': -50...
#
#                    market_cap_change_24h_in_currency  \
# 0  {'aed': -5906882138.742058, 'ars': -2039380894...
#
#         market_cap_change_percentage_24h_in_currency  total_supply  \
# 0  {'aed': -8.81809, 'ars': -8.65819, 'aud': -8.4...  4.500000e+10
#
#      max_supply  circulating_supply              last_updated
# 0  4.500000e+10        3.382026e+10  2022-07-21T07:55:07.459Z
#
# [1 rows x 42 columns]

# %%
market_data = []

#TODO community_data, developer_data, metrics

for index, row in df.iterrows():
    try: 
        data = ast.literal_eval(row['market_data_cg'])
    except ValueError:
        None
    data['name_ms'] = row['name_ms']
    market_data.append(pd.json_normalize(data, max_level=0).iloc[0].to_dict())
market_data = pd.DataFrame(market_data)

# %%
metrics_data = []

#TODO community_data, developer_data, metrics

for index, row in df.iterrows():
    try:
        metrics = ast.literal_eval(row['metrics_ms'])
    except ValueError:
        None
    metrics['name_ms'] = row['name_ms']
    metrics_data.append(pd.json_normalize(metrics, max_level=0).iloc[0].to_dict())
metrics_data = pd.DataFrame(metrics_data)

# %%
community_data = []

#TODO community_data, developer_data, metrics

for index, row in df.iterrows():
    try:
        data = ast.literal_eval(row['community_data_cg'])
    except ValueError:
        None
    data['name_ms'] = row['name_ms']
    community_data.append(pd.json_normalize(data, max_level=0).iloc[0].to_dict())
community_data = pd.DataFrame(community_data)

# %%
profile_data = []

#TODO community_data, developer_data, metrics

for index, row in df.iterrows():
    try:
        profile = ast.literal_eval(row['profile_ms'])
    except ValueError:
        None
    profile['name_ms'] = row['name_ms']
    profile_data.append(pd.json_normalize(profile, max_level=0).iloc[0].to_dict())

# %%
profile_data = pd.DataFrame(profile_data)

# %%
df = df.merge(profile_data, how='outer', on='name_ms')
df = df.merge(market_data, how='outer', on='name_ms')
df = df.merge(metrics_data, how='outer', on='name_ms')
df = df.merge(community_data, how='outer', on='name_ms')

# %%
print(df.columns.tolist())
# Out:
# ['id_ms', 'serial_id_ms', 'symbol_ms_x', 'name_ms', 'slug_ms', 'contract_addresses_ms', '_internal_temp_agora_id_ms', 'metrics_ms', 'profile_ms', 'id_cg', 'symbol_ms_y', 'image_x_cg', 'current_price_cg', 'market_cap_cg', 'market_cap_rank_x_cg', 'fully_diluted_valuation_cg', 'total_volume_cg', 'high_24h_cg', 'low_24h_cg', 'price_change_24h_cg', 'price_change_percentage_24h_cg', 'market_cap_change_24h_cg', 'market_cap_change_percentage_24h_cg', 'circulating_supply_cg', 'total_supply_cg', 'max_supply_cg', 'ath_cg', 'ath_change_percentage_cg', 'ath_date_cg', 'atl_cg', 'atl_change_percentage_cg', 'atl_date_cg', 'roi_cg', 'last_updated_x_cg', 'symbol_y_cg', 'name_y_cg', 'asset_platform_id_cg', 'platforms_cg', 'block_time_in_minutes_cg', 'hashing_algorithm_cg', 'categories_cg', 'public_notice_cg', 'additional_notices_cg', 'localization_cg', 'description_cg', 'links_cg', 'image_y_cg', 'country_origin_cg', 'genesis_date_cg', 'sentiment_votes_up_percentage_cg', 'sentiment_votes_down_percentage_cg', 'market_cap_rank_y_cg', 'coingecko_rank_cg', 'coingecko_score_cg', 'developer_score_cg', 'community_score_cg', 'liquidity_score_cg', 'public_interest_score_cg', 'market_data_cg', 'community_data_cg', 'developer_data_cg', 'public_interest_stats_cg', 'status_updates_cg', 'last_updated_y_cg', 'tickers_cg', 'ico_data_cg', 'contract_address_cg', 'general', 'contributors', 'advisors', 'investors', 'ecosystem', 'economics', 'technology', 'governance', 'metadata', 'current_price', 'total_value_locked', 'mcap_to_tvl_ratio', 'fdv_to_tvl_ratio', 'roi', 'ath', 'ath_change_percentage', 'ath_date', 'atl', 'atl_change_percentage', 'atl_date', 'market_cap', 'market_cap_rank', 'fully_diluted_valuation', 'total_volume', 'high_24h', 'low_24h', 'price_change_24h', 'price_change_percentage_24h', 'price_change_percentage_7d', 'price_change_percentage_14d', 'price_change_percentage_30d', 'price_change_percentage_60d', 'price_change_percentage_200d', 'price_change_percentage_1y', 'market_cap_change_24h', 'market_cap_change_percentage_24h', 'price_change_24h_in_currency', 'price_change_percentage_1h_in_currency', 'price_change_percentage_24h_in_currency', 'price_change_percentage_7d_in_currency', 'price_change_percentage_14d_in_currency', 'price_change_percentage_30d_in_currency', 'price_change_percentage_60d_in_currency', 'price_change_percentage_200d_in_currency', 'price_change_percentage_1y_in_currency', 'market_cap_change_24h_in_currency', 'market_cap_change_percentage_24h_in_currency', 'total_supply', 'max_supply', 'circulating_supply', 'last_updated', 'market_data', 'marketcap', 'supply', 'blockchain_stats_24_hours', 'market_data_liquidity', 'all_time_high', 'cycle_low', 'token_sale_stats', 'mining_stats', 'developer_activity', 'roi_data', 'roi_by_year', 'risk_metrics', 'misc_data', 'reddit', 'on_chain_data', 'exchange_flows', 'miner_flows', 'supply_activity', 'supply_distribution', 'alert_messages', 'facebook_likes', 'twitter_followers', 'reddit_average_posts_48h', 'reddit_average_comments_48h', 'reddit_subscribers', 'reddit_accounts_active_48h', 'telegram_channel_user_count']

# %%
df.drop(['market_data_cg', 'metrics_ms', 'community_data_cg', 'profile_ms', 'id_ms', 'serial_id_ms', '_internal_temp_agora_id_ms', 'public_notice_cg', 'additional_notices_cg', 'localization_cg', 'country_origin_cg', 'status_updates_cg'], axis=1, inplace=True)

# %%
# Out:
#                                    id_ms  serial_id_ms symbol_ms_x  \
# 0   1e31218a-e44e-4285-820c-8282ee222035          6057         BTC
# 1   21c795f5-1bfd-40c3-858e-e9d7e820c6d0          6059         ETH
# 2   51f8ea5e-f426-4f40-939a-db7e05495374           140        USDT
# 3   4515ba15-2719-4183-b0ca-b9255d55b67e          6071        USDC
# 4   7dc551ba-cfed-4437-a027-386044415e3e           347         BNB
# 5   5da7bde4-61e9-4a6f-9fc3-7ed66effb198            29        BUSD
# 6   97775be0-2608-4720-b7af-f85b24c7eb2d          6238         XRP
# 7   362f0140-ecdd-4205-b8a0-36f0fd5d8167          6058         ADA
# 8   b3d5d66c-26a2-404c-9325-91dc714a722b          6079         SOL
# 9   7d793fa7-5fc6-432a-b26b-d1b10769d42e            91        DOGE
# 10  da6a0575-ec95-4c47-855d-5fc6a3e22ada           373         DOT
# 11  a3b64831-4288-48bd-a3e7-eb4f77f6f740          6055         DAI
# 12  4b474270-99ba-4a18-869d-11cd3fc0201a            62       MATIC
# 13  2db6b38a-681a-4514-9d67-691e319597ee          1265        AVAX
# 14  8c4f84a7-6484-4074-8c17-fe363a243e7f          6195        SHIB
# 15  1c077d6e-99c7-491c-b24d-1d359011cd81           609         TRX
# 16  81bbf507-29d5-4458-8d42-b81d7c197996          5897        WBTC
# 17  1d51479d-68f6-4886-8644-2a55ea9007bf          5915         UNI
# 18  28681c70-d3a1-4139-942e-c4bdcc49ad64           845         LEO
# 19  c7c3697d-1b9c-42bf-9664-a366634ce2b3          6093         LTC
#
#             name_ms          slug_ms  \
# 0           Bitcoin          bitcoin
# 1          Ethereum         ethereum
# 2            Tether           tether
# 3          USD Coin         usd-coin
# 4               BNB     binance-coin
# 5       Binance USD      binance-usd
# 6               XRP              xrp
# 7           Cardano          cardano
# 8            Solana           solana
# 9          Dogecoin         dogecoin
# 10         Polkadot         polkadot
# 11              Dai              dai
# 12          Polygon          polygon
# 13        Avalanche        avalanche
# 14        Shiba Inu        shiba-inu
# 15             TRON             tron
# 16  Wrapped Bitcoin  wrapped-bitcoin
# 17          Uniswap          uniswap
# 18     Unus Sed Leo     unus-sed-leo
# 19         Litecoin         litecoin
#
#                                 contract_addresses_ms  \
# 0                                                 NaN
# 1                                                 NaN
# 2   [{'platform': 'polygon-pos', 'contract_address...
# 3   [{'platform': 'milkomeda-cardano', 'contract_a...
# 4                                                 NaN
# 5   [{'platform': 'iotex', 'contract_address': '0x...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  [{'platform': 'arbitrum-one', 'contract_addres...
# 12  [{'platform': 'ethereum', 'contract_address': ...
# 13  [{'platform': 'moonbeam', 'contract_address': ...
# 14  [{'platform': 'ethereum', 'contract_address': ...
# 15                                                NaN
# 16  [{'platform': 'moonbeam', 'contract_address': ...
# 17  [{'platform': 'xdai', 'contract_address': '0x4...
# 18  [{'platform': 'sora', 'contract_address': '0x0...
# 19                                                NaN
#
#               _internal_temp_agora_id_ms  \
# 0   9793eae6-f374-46b4-8764-c2d224429791
# 1   263d8b01-5a96-41f0-85d5-09687bbbf7ca
# 2   1eaf063a-b8dd-4cfb-95dd-a06338565720
# 3   df532106-d330-46aa-b0fb-1b51f201e80e
# 4   3f1d591f-979c-453b-954b-aa90edf29a2a
# 5   39bd959a-d4d5-4dd0-b99f-75bb6ba189cd
# 6   f0cd1362-726d-494f-8fac-b656944f76b5
# 7   bef28e0d-413c-45bb-99e0-f09516a12191
# 8   1f8f561c-8308-47ee-bb0f-c142215798bd
# 9   683e1999-91b6-434f-91a6-4b14e7d9e4b6
# 10  06b2065f-b4c4-4932-8737-23226fb73668
# 11  8b8a7fe3-65ad-41ed-9a0c-3292d3db50e0
# 12  0711618b-58f6-4504-9557-aab05ef8b623
# 13  c280608d-e955-47e4-ab9e-3508a6ad969d
# 14  4a6d2032-1764-4dd6-b8bc-d1d94b7fc5ab
# 15  24d8eb2f-aed0-42ab-b443-d1e3aa27a6d4
# 16  eade44a5-2152-4a30-8c5b-d75e5ab5749b
# 17  d32b98a8-7160-480b-a331-fa294aa25301
# 18  ad8fb662-6685-4e11-8b48-5a5da0d7366c
# 19  eb06508b-bbc6-4202-bf40-a9e9f8d066cf
#
#                                            metrics_ms  \
# 0   {'market_data': {'price_usd': 23007.5327492716...
# 1   {'market_data': {'price_usd': 1489.25257896044...
# 2   {'market_data': {'price_usd': 0.99990948326514...
# 3   {'market_data': {'price_usd': 1, 'price_btc': ...
# 4   {'market_data': {'price_usd': 256.334565336979...
# 5   {'market_data': {'price_usd': 1, 'price_btc': ...
# 6   {'market_data': {'price_usd': 0.35603558578829...
# 7   {'market_data': {'price_usd': 0.49182463111033...
# 8   {'market_data': {'price_usd': 41.112137987667,...
# 9   {'market_data': {'price_usd': 0.06895204150214...
# 10  {'market_data': {'price_usd': 7.38337243997815...
# 11  {'market_data': {'price_usd': 0.99976462314740...
# 12  {'market_data': {'price_usd': 0.87070970480869...
# 13  {'market_data': {'price_usd': 23.5754476833682...
# 14  {'market_data': {'price_usd': 1.18286380290200...
# 15  {'market_data': {'price_usd': 0.06718041319353...
# 16  {'market_data': {'price_usd': 23006.7545861459...
# 17  {'market_data': {'price_usd': 6.84993986943651...
# 18  {'market_data': {'price_usd': 5.23196763992021...
# 19  {'market_data': {'price_usd': 56.5565766106674...
#
#                                            profile_ms          id_cg  ...  \
# 0   {'general': {'overview': {'is_verified': False...        bitcoin  ...
# 1   {'general': {'overview': {'is_verified': False...       ethereum  ...
# 2   {'general': {'overview': {'is_verified': False...         tether  ...
# 3   {'general': {'overview': {'is_verified': False...       usd-coin  ...
# 4   {'general': {'overview': {'is_verified': False...    binancecoin  ...
# 5   {'general': {'overview': {'is_verified': False...    binance-usd  ...
# 6   {'general': {'overview': {'is_verified': False...         ripple  ...
# 7   {'general': {'overview': {'is_verified': False...        cardano  ...
# 8   {'general': {'overview': {'is_verified': True,...         solana  ...
# 9   {'general': {'overview': {'is_verified': False...       dogecoin  ...
# 10  {'general': {'overview': {'is_verified': False...       polkadot  ...
# 11  {'general': {'overview': {'is_verified': False...            dai  ...
# 12  {'general': {'overview': {'is_verified': False...  matic-network  ...
# 13  {'general': {'overview': {'is_verified': False...    avalanche-2  ...
# 14  {'general': {'overview': {'is_verified': False...      shiba-inu  ...
# 15  {'general': {'overview': {'is_verified': False...            NaN  ...
# 16  {'general': {'overview': {'is_verified': False...            NaN  ...
# 17  {'general': {'overview': {'is_verified': False...            NaN  ...
# 18  {'general': {'overview': {'is_verified': False...            NaN  ...
# 19  {'general': {'overview': {'is_verified': False...            NaN  ...
#
#                                       supply_activity  \
# 0   {'supply_active_10y': 16559717.81078758, 'supp...
# 1   {'supply_active_10y': 116413255.25562388, 'sup...
# 2   {'supply_active_10y': 888000000, 'supply_activ...
# 3   {'supply_active_10y': 44700575099.28983, 'supp...
# 4   {'supply_active_10y': None, 'supply_active_180...
# 5   {'supply_active_10y': 17929626189.261562, 'sup...
# 6   {'supply_active_10y': 99927904530.58588, 'supp...
# 7   {'supply_active_10y': 27780908174.489346, 'sup...
# 8   {'supply_active_10y': None, 'supply_active_180...
# 9   {'supply_active_10y': 134485536909.47081, 'sup...
# 10  {'supply_active_10y': None, 'supply_active_180...
# 11  {'supply_active_10y': 6244592529.217166, 'supp...
# 12  {'supply_active_10y': None, 'supply_active_180...
# 13  {'supply_active_10y': None, 'supply_active_180...
# 14  {'supply_active_10y': None, 'supply_active_180...
# 15  {'supply_active_10y': None, 'supply_active_180...
# 16  {'supply_active_10y': 236880.12606246, 'supply...
# 17  {'supply_active_10y': 1000000000, 'supply_acti...
# 18  {'supply_active_10y': None, 'supply_active_180...
# 19  {'supply_active_10y': 70036025.91888279, 'supp...
#
#                                   supply_distribution  alert_messages  \
# 0   {'supply_in_addresses_balance_greater_0_001_na...            None
# 1   {'supply_in_addresses_balance_greater_0_001_na...            None
# 2   {'supply_in_addresses_balance_greater_0_001_na...            None
# 3   {'supply_in_addresses_balance_greater_0_001_na...            None
# 4   {'supply_in_addresses_balance_greater_0_001_na...            None
# 5   {'supply_in_addresses_balance_greater_0_001_na...            None
# 6   {'supply_in_addresses_balance_greater_0_001_na...            None
# 7   {'supply_in_addresses_balance_greater_0_001_na...            None
# 8   {'supply_in_addresses_balance_greater_0_001_na...            None
# 9   {'supply_in_addresses_balance_greater_0_001_na...            None
# 10  {'supply_in_addresses_balance_greater_0_001_na...            None
# 11  {'supply_in_addresses_balance_greater_0_001_na...            None
# 12  {'supply_in_addresses_balance_greater_0_001_na...            None
# 13  {'supply_in_addresses_balance_greater_0_001_na...            None
# 14  {'supply_in_addresses_balance_greater_0_001_na...            None
# 15  {'supply_in_addresses_balance_greater_0_001_na...            None
# 16  {'supply_in_addresses_balance_greater_0_001_na...            None
# 17  {'supply_in_addresses_balance_greater_0_001_na...            None
# 18  {'supply_in_addresses_balance_greater_0_001_na...            None
# 19  {'supply_in_addresses_balance_greater_0_001_na...            None
#
#     facebook_likes  twitter_followers  reddit_average_posts_48h  \
# 0             None            5402303                     6.692
# 1             None            2693776                     3.583
# 2             None             279341                     0.000
# 3             None              93341                     0.000
# 4             None            9206895                     4.727
# 5             None              32711                     0.000
# 6             None            2525213                     0.692
# 7             None             850279                     2.385
# 8             None            1956067                     1.700
# 9             None            3433575                     7.400
# 10            None            1325634                     0.857
# 11            None             226123                     0.500
# 12            None            1583182                     0.000
# 13            None             714913                     0.500
# 14            None            3422384                     2.889
# 15            None            3422384                     2.889
# 16            None            3422384                     2.889
# 17            None            3422384                     2.889
# 18            None            3422384                     2.889
# 19            None            3422384                     2.889
#
#     reddit_average_comments_48h  reddit_subscribers  \
# 0                       735.615             4412851
# 1                       137.750             1349995
# 2                         0.000                   0
# 3                         0.000                   0
# 4                        67.455              867693
# 5                         0.000                   0
# 6                        15.538              351496
# 7                        64.077              700039
# 8                        45.100              150053
# 9                       178.400             2305794
# 10                        4.286               40490
# 11                        3.167               34038
# 12                        0.000                   0
# 13                        8.917               40524
# 14                      170.222              474699
# 15                      170.222              474699
# 16                      170.222              474699
# 17                      170.222              474699
# 18                      170.222              474699
# 19                      170.222              474699
#
#     reddit_accounts_active_48h  telegram_channel_user_count
# 0                        11949                          NaN
# 1                         2669                          NaN
# 2                            0                          NaN
# 3                            0                          NaN
# 4                         1300                          NaN
# 5                            0                          NaN
# 6                          555                          NaN
# 7                         2155                      37773.0
# 8                          953                      79836.0
# 9                         5979                          NaN
# 10                          53                      34874.0
# 11                         246                      14727.0
# 12                           0                      25252.0
# 13                         414                      47658.0
# 14                        2343                      77075.0
# 15                        2343                      77075.0
# 16                        2343                      77075.0
# 17                        2343                      77075.0
# 18                        2343                      77075.0
# 19                        2343                      77075.0
#
# [20 rows x 146 columns]

# %%
df.to_csv('../data/coin_data.csv')
