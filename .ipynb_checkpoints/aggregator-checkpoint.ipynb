# %%
import pandas as pd
import numpy as np

# %%
messari = pd.read_csv('../data/messari.csv', index_col=0)
cg = pd.read_csv('../data/cg.csv', index_col=0)

# %%
messari.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       20 non-null     object
#  1   serial_id                20 non-null     int64
#  2   symbol                   20 non-null     object
#  3   name                     20 non-null     object
#  4   slug                     20 non-null     object
#  5   contract_addresses       10 non-null     object
#  6   _internal_temp_agora_id  20 non-null     object
#  7   metrics                  20 non-null     object
#  8   profile                  20 non-null     object
# dtypes: int64(1), object(8)
# memory usage: 1.6+ KB

# %%
# Out:
#             id symbol_x    name_x  \
# 0      bitcoin      btc   Bitcoin
# 1     ethereum      eth  Ethereum
# 2       tether     usdt    Tether
# 3     usd-coin     usdc  USD Coin
# 4  binancecoin      bnb       BNB
#
#                                              image_x  current_price  \
# 0  https://assets.coingecko.com/coins/images/1/la...      22090.000
# 1  https://assets.coingecko.com/coins/images/279/...       1471.310
# 2  https://assets.coingecko.com/coins/images/325/...          1.001
# 3  https://assets.coingecko.com/coins/images/6319...          1.000
# 4  https://assets.coingecko.com/coins/images/825/...        260.410
#
#      market_cap  market_cap_rank_x  fully_diluted_valuation  total_volume  \
# 0  422510243995                  1             4.646159e+11   45078871627
# 1  176544396623                  2                      NaN   22088433163
# 2   65798448123                  3                      NaN   61414197652
# ...

# %%
cg.rename(columns={"symbol_x": "symbol", "name_x": "name"}, inplace=True)

# %%
cg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 0 to 14
# Data columns (total 59 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                15 non-null     object
#  1   symbol                            15 non-null     object
#  2   name                              15 non-null     object
#  3   image_x                           15 non-null     object
#  4   current_price                     15 non-null     float64
#  5   market_cap                        15 non-null     int64
#  6   market_cap_rank_x                 15 non-null     int64
#  7   fully_diluted_valuation           7 non-null      float64
#  8   total_volume                      15 non-null     int64
#  9   high_24h                          15 non-null     float64
#  10  low_24h                           15 non-null     float64
# ...

# %%
df = messari.merge(cg, how='outer', on='name')
# Out:
# C:\Users\tomce\AppData\Local\Temp\ipykernel_1632\217557444.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'symbol_y'} in the result is deprecated and will raise a MergeError in a future version.
#   df = messari.merge(cg, how='outer', on='name')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 0 to 19
# Data columns (total 67 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id_x                              20 non-null     object
#  1   serial_id                         20 non-null     int64
#  2   symbol_x                          20 non-null     object
#  3   name                              20 non-null     object
#  4   slug                              20 non-null     object
#  5   contract_addresses                10 non-null     object
#  6   _internal_temp_agora_id           20 non-null     object
#  7   metrics                           20 non-null     object
#  8   profile                           20 non-null     object
#  9   id_y                              15 non-null     object
#  10  symbol_y                          15 non-null     object
# ...
