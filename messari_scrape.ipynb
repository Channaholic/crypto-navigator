# %%
import pandas as pd
import numpy as np
import requests
import json

# %%
url = "https://data.messari.io/api/v2/"
headers = { 'Content-type': 'application/json'}
payload = {'page': '1'}

# %%
r = requests.get(url + 'assets',params=payload, headers = headers).json()

# %%
df = pd.DataFrame.from_dict(r['data'])

# %%
df
# Out:
#                                       id  serial_id symbol             name  \
# 0   1e31218a-e44e-4285-820c-8282ee222035       6057    BTC          Bitcoin
# 1   21c795f5-1bfd-40c3-858e-e9d7e820c6d0       6059    ETH         Ethereum
# 2   51f8ea5e-f426-4f40-939a-db7e05495374        140   USDT           Tether
# 3   4515ba15-2719-4183-b0ca-b9255d55b67e       6071   USDC         USD Coin
# 4   7dc551ba-cfed-4437-a027-386044415e3e        347    BNB              BNB
# 5   5da7bde4-61e9-4a6f-9fc3-7ed66effb198         29   BUSD      Binance USD
# 6   97775be0-2608-4720-b7af-f85b24c7eb2d       6238    XRP              XRP
# 7   362f0140-ecdd-4205-b8a0-36f0fd5d8167       6058    ADA          Cardano
# 8   b3d5d66c-26a2-404c-9325-91dc714a722b       6079    SOL           Solana
# 9   7d793fa7-5fc6-432a-b26b-d1b10769d42e         91   DOGE         Dogecoin
# 10  a3b64831-4288-48bd-a3e7-eb4f77f6f740       6055    DAI              Dai
# 11  da6a0575-ec95-4c47-855d-5fc6a3e22ada        373    DOT         Polkadot
# 12  1c077d6e-99c7-491c-b24d-1d359011cd81        609    TRX             TRON
# 13  8c4f84a7-6484-4074-8c17-fe363a243e7f       6195   SHIB        Shiba Inu
# 14  2db6b38a-681a-4514-9d67-691e319597ee       1265   AVAX        Avalanche
# 15  4b474270-99ba-4a18-869d-11cd3fc0201a         62  MATIC          Polygon
# 16  1d51479d-68f6-4886-8644-2a55ea9007bf       5915    UNI          Uniswap
# 17  28681c70-d3a1-4139-942e-c4bdcc49ad64        845    LEO     Unus Sed Leo
# 18  81bbf507-29d5-4458-8d42-b81d7c197996       5897   WBTC  Wrapped Bitcoin
# 19  c7c3697d-1b9c-42bf-9664-a366634ce2b3       6093    LTC         Litecoin
#
#                slug                                 contract_addresses  \
# 0           bitcoin                                               None
# 1          ethereum                                               None
# 2            tether  [{'platform': 'boba', 'contract_address': '0x5...
# 3          usd-coin  [{'platform': 'polygon-pos', 'contract_address...
# 4      binance-coin                                               None
# 5       binance-usd  [{'platform': 'theta', 'contract_address': '0x...
# 6               xrp                                               None
# 7           cardano                                               None
# 8            solana                                               None
# 9          dogecoin                                               None
# 10              dai  [{'platform': 'ethereum', 'contract_address': ...
# 11         polkadot                                               None
# 12             tron                                               None
# 13        shiba-inu  [{'platform': 'ethereum', 'contract_address': ...
# 14        avalanche  [{'platform': 'polygon-pos', 'contract_address...
# 15          polygon  [{'platform': 'moonbeam', 'contract_address': ...
# 16          uniswap  [{'platform': 'arbitrum-one', 'contract_addres...
# 17     unus-sed-leo  [{'platform': 'sora', 'contract_address': '0x0...
# 18  wrapped-bitcoin  [{'platform': 'tomochain', 'contract_address':...
# 19         litecoin                                               None
#
#                  _internal_temp_agora_id  \
# 0   9793eae6-f374-46b4-8764-c2d224429791
# 1   263d8b01-5a96-41f0-85d5-09687bbbf7ca
# 2   1eaf063a-b8dd-4cfb-95dd-a06338565720
# 3   df532106-d330-46aa-b0fb-1b51f201e80e
# 4   3f1d591f-979c-453b-954b-aa90edf29a2a
# 5   39bd959a-d4d5-4dd0-b99f-75bb6ba189cd
# 6   f0cd1362-726d-494f-8fac-b656944f76b5
# 7   bef28e0d-413c-45bb-99e0-f09516a12191
# 8   1f8f561c-8308-47ee-bb0f-c142215798bd
# 9   683e1999-91b6-434f-91a6-4b14e7d9e4b6
# 10  8b8a7fe3-65ad-41ed-9a0c-3292d3db50e0
# 11  06b2065f-b4c4-4932-8737-23226fb73668
# 12  24d8eb2f-aed0-42ab-b443-d1e3aa27a6d4
# 13  4a6d2032-1764-4dd6-b8bc-d1d94b7fc5ab
# 14  c280608d-e955-47e4-ab9e-3508a6ad969d
# 15  0711618b-58f6-4504-9557-aab05ef8b623
# 16  d32b98a8-7160-480b-a331-fa294aa25301
# 17  ad8fb662-6685-4e11-8b48-5a5da0d7366c
# 18  eade44a5-2152-4a30-8c5b-d75e5ab5749b
# 19  eb06508b-bbc6-4202-bf40-a9e9f8d066cf
#
#                                               metrics  \
# 0   {'market_data': {'price_usd': 20926.3404725021...
# 1   {'market_data': {'price_usd': 1222.50955894840...
# 2   {'market_data': {'price_usd': 0.99936106541334...
# 3   {'market_data': {'price_usd': 1, 'price_btc': ...
# 4   {'market_data': {'price_usd': 239.254605755473...
# 5   {'market_data': {'price_usd': 1, 'price_btc': ...
# 6   {'market_data': {'price_usd': 0.34080339958397...
# 7   {'market_data': {'price_usd': 0.44199621901770...
# 8   {'market_data': {'price_usd': 38.3100019977654...
# 9   {'market_data': {'price_usd': 0.06382534645000...
# 10  {'market_data': {'price_usd': 0.99990567831855...
# 11  {'market_data': {'price_usd': 6.89918814969459...
# 12  {'market_data': {'price_usd': 0.06771567549588...
# 13  {'market_data': {'price_usd': 1.09138594724321...
# 14  {'market_data': {'price_usd': 20.0487465685309...
# 15  {'market_data': {'price_usd': 0.70594743034305...
# 16  {'market_data': {'price_usd': 7.00293391781737...
# 17  {'market_data': {'price_usd': 5.25251790487480...
# 18  {'market_data': {'price_usd': 20923.1119059682...
# 19  {'market_data': {'price_usd': 51.3672286910965...
#
#                                               profile
# 0   {'general': {'overview': {'is_verified': False...
# 1   {'general': {'overview': {'is_verified': False...
# 2   {'general': {'overview': {'is_verified': False...
# 3   {'general': {'overview': {'is_verified': False...
# 4   {'general': {'overview': {'is_verified': False...
# 5   {'general': {'overview': {'is_verified': False...
# 6   {'general': {'overview': {'is_verified': False...
# 7   {'general': {'overview': {'is_verified': False...
# 8   {'general': {'overview': {'is_verified': True,...
# 9   {'general': {'overview': {'is_verified': False...
# 10  {'general': {'overview': {'is_verified': False...
# 11  {'general': {'overview': {'is_verified': False...
# 12  {'general': {'overview': {'is_verified': False...
# 13  {'general': {'overview': {'is_verified': False...
# 14  {'general': {'overview': {'is_verified': False...
# 15  {'general': {'overview': {'is_verified': False...
# 16  {'general': {'overview': {'is_verified': False...
# 17  {'general': {'overview': {'is_verified': False...
# 18  {'general': {'overview': {'is_verified': False...
# 19  {'general': {'overview': {'is_verified': False...
